# %%
'''
Test on filtered 20NewsGroup dataset
supervised one layer
'''
save_PATH = 'saved_data/'
save_filename = 'supervised_one_layer_pinv'

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import sys
package_dir = '../full_backprop_package/'
sys.path.append(package_dir)
from deep_nmf import Deep_NMF, Fro_Norm
from pinv import PinvF
from writer import Writer

# %%
from data_loading import sparsedata_L2, data, Y1

# %%
n = data.shape[0]
m = data.shape[1]
k1 = 20
k2 = 6
net = Deep_NMF([m, k1])
criterion = Fro_Norm()
pinv = PinvF.apply
dataset = sparsedata_L2(1000*data, 1000*Y1)

# %%
lr = 5000
batchsize = 500
lambd = 1e-4
epoch = 25
loss_lst = []
for epo in range(epoch):
    total_loss = 0
    dataloader = torch.utils.data.DataLoader(dataset, batch_size = batchsize, shuffle = True)
    for (i,(inputs, label)) in enumerate(dataloader):
        net.zero_grad()
        
        inputs = torch.reshape(inputs, [inputs.shape[0], inputs.shape[2]])
        label = torch.reshape(label, [label.shape[0], label.shape[2]])
        inputs, label = Variable(inputs), Variable(label.double())
        
        S_lst = net(inputs)
        S = S_lst[-1]
        B = torch.mm(pinv(S), label)
        pred = torch.mm(S,B)
        
        loss1 = criterion(torch.mm(S, net.lsqnonneglst[0].A), inputs)
        loss2 = criterion(pred, label)
        loss = loss1 + lambd*loss2
        print('epoch = ', epo, 'batch = ',i)
        print(loss.data, loss1.data, lambd*loss2.data)
        sys.stdout.flush()
        loss_lst.append(loss.data)
        total_loss += loss.data
        
        loss.backward()
        for A in net.parameters():
            A.data = A.data.sub_(lr*A.grad.data)
            A.data = A.data.clamp(min = 0)

    print('epoch = ', epo)
    print('total_loss = ', total_loss)
# Out:
# epoch =  0 batch =  0
# tensor(12.2869, dtype=torch.float64) tensor(7.7475, dtype=torch.float64) tensor(4.5393, dtype=torch.float64)
# epoch =  0 batch =  1
# tensor(11.7049, dtype=torch.float64) tensor(7.8252, dtype=torch.float64) tensor(3.8797, dtype=torch.float64)
# epoch =  0 batch =  2
# tensor(11.2156, dtype=torch.float64) tensor(7.6946, dtype=torch.float64) tensor(3.5210, dtype=torch.float64)
# epoch =  0 batch =  3
# tensor(11.0294, dtype=torch.float64) tensor(7.7894, dtype=torch.float64) tensor(3.2400, dtype=torch.float64)
# epoch =  0 batch =  4
# tensor(10.7796, dtype=torch.float64) tensor(7.7404, dtype=torch.float64) tensor(3.0392, dtype=torch.float64)
# epoch =  0 batch =  5
# tensor(10.7859, dtype=torch.float64) tensor(7.8516, dtype=torch.float64) tensor(2.9343, dtype=torch.float64)
# epoch =  0 batch =  6
# tensor(10.6462, dtype=torch.float64) tensor(7.7705, dtype=torch.float64) tensor(2.8757, dtype=torch.float64)
# epoch =  0 batch =  7
# tensor(10.7568, dtype=torch.float64) tensor(7.8510, dtype=torch.float64) tensor(2.9058, dtype=torch.float64)
# epoch =  0 batch =  8
# tensor(10.5562, dtype=torch.float64) tensor(7.8334, dtype=torch.float64) tensor(2.7228, dtype=torch.float64)
# epoch =  0 batch =  9
# tensor(10.5667, dtype=torch.float64) tensor(7.8320, dtype=torch.float64) tensor(2.7347, dtype=torch.float64)
# epoch =  0 batch =  10
# tensor(10.5239, dtype=torch.float64) tensor(7.8798, dtype=torch.float64) tensor(2.6441, dtype=torch.float64)
# epoch =  0 batch =  11
# tensor(10.4484, dtype=torch.float64) tensor(7.8156, dtype=torch.float64) tensor(2.6328, dtype=torch.float64)
# epoch =  0 batch =  12
# tensor(10.5147, dtype=torch.float64) tensor(7.8472, dtype=torch.float64) tensor(2.6675, dtype=torch.float64)
# epoch =  0 batch =  13
# tensor(10.4090, dtype=torch.float64) tensor(7.8468, dtype=torch.float64) tensor(2.5621, dtype=torch.float64)
# epoch =  0 batch =  14
# tensor(10.4202, dtype=torch.float64) tensor(7.8142, dtype=torch.float64) tensor(2.6060, dtype=torch.float64)
# epoch =  0 batch =  15
# tensor(10.3561, dtype=torch.float64) tensor(7.8300, dtype=torch.float64) tensor(2.5260, dtype=torch.float64)
# epoch =  0 batch =  16
# tensor(10.2348, dtype=torch.float64) tensor(7.7502, dtype=torch.float64) tensor(2.4846, dtype=torch.float64)
# epoch =  0 batch =  17
# tensor(10.2747, dtype=torch.float64) tensor(7.8294, dtype=torch.float64) tensor(2.4453, dtype=torch.float64)
# epoch =  0 batch =  18
# tensor(10.3624, dtype=torch.float64) tensor(7.8146, dtype=torch.float64) tensor(2.5478, dtype=torch.float64)
# epoch =  0 batch =  19
# tensor(10.3317, dtype=torch.float64) tensor(7.8292, dtype=torch.float64) tensor(2.5025, dtype=torch.float64)
# epoch =  0 batch =  20
# tensor(10.3836, dtype=torch.float64) tensor(7.8611, dtype=torch.float64) tensor(2.5224, dtype=torch.float64)
# epoch =  0 batch =  21
# tensor(10.2526, dtype=torch.float64) tensor(7.8450, dtype=torch.float64) tensor(2.4076, dtype=torch.float64)
# epoch =  0 batch =  22
# tensor(10.1474, dtype=torch.float64) tensor(7.6832, dtype=torch.float64) tensor(2.4643, dtype=torch.float64)
# epoch =  0 batch =  23
# tensor(10.1998, dtype=torch.float64) tensor(7.7811, dtype=torch.float64) tensor(2.4187, dtype=torch.float64)
# epoch =  0 batch =  24
# tensor(10.0785, dtype=torch.float64) tensor(7.7948, dtype=torch.float64) tensor(2.2837, dtype=torch.float64)
# epoch =  0 batch =  25
# tensor(10.3242, dtype=torch.float64) tensor(7.8283, dtype=torch.float64) tensor(2.4960, dtype=torch.float64)
# epoch =  0 batch =  26
# tensor(10.3500, dtype=torch.float64) tensor(7.8451, dtype=torch.float64) tensor(2.5049, dtype=torch.float64)
# epoch =  0 batch =  27
# tensor(10.1529, dtype=torch.float64) tensor(7.7936, dtype=torch.float64) tensor(2.3593, dtype=torch.float64)
# epoch =  0 batch =  28
# tensor(10.2005, dtype=torch.float64) tensor(7.8437, dtype=torch.float64) tensor(2.3567, dtype=torch.float64)
# epoch =  0 batch =  29
# tensor(10.2163, dtype=torch.float64) tensor(7.7619, dtype=torch.float64) tensor(2.4544, dtype=torch.float64)
# epoch =  0 batch =  30
# tensor(9.9971, dtype=torch.float64) tensor(7.7461, dtype=torch.float64) tensor(2.2509, dtype=torch.float64)
# epoch =  0 batch =  31
# tensor(10.1627, dtype=torch.float64) tensor(7.8104, dtype=torch.float64) tensor(2.3523, dtype=torch.float64)
# epoch =  0 batch =  32
# tensor(10.2082, dtype=torch.float64) tensor(7.7775, dtype=torch.float64) tensor(2.4307, dtype=torch.float64)
# epoch =  0 batch =  33
# tensor(10.1737, dtype=torch.float64) tensor(7.7947, dtype=torch.float64) tensor(2.3790, dtype=torch.float64)
# epoch =  0 batch =  34
# tensor(9.9645, dtype=torch.float64) tensor(7.8414, dtype=torch.float64) tensor(2.1231, dtype=torch.float64)
# epoch =  0 batch =  35
# tensor(10.3793, dtype=torch.float64) tensor(7.7941, dtype=torch.float64) tensor(2.5852, dtype=torch.float64)
# epoch =  0 batch =  36
# tensor(10.0061, dtype=torch.float64) tensor(7.7291, dtype=torch.float64) tensor(2.2770, dtype=torch.float64)
# epoch =  0 batch =  37
# tensor(10.0009, dtype=torch.float64) tensor(7.8229, dtype=torch.float64) tensor(2.1780, dtype=torch.float64)
# epoch =  0
# total_loss =  tensor(397.4022, dtype=torch.float64)
# epoch =  1 batch =  0
# tensor(9.4695, dtype=torch.float64) tensor(7.7274, dtype=torch.float64) tensor(1.7421, dtype=torch.float64)
# epoch =  1 batch =  1
# tensor(9.6416, dtype=torch.float64) tensor(7.8393, dtype=torch.float64) tensor(1.8023, dtype=torch.float64)
# epoch =  1 batch =  2
# tensor(9.5202, dtype=torch.float64) tensor(7.7923, dtype=torch.float64) tensor(1.7280, dtype=torch.float64)
# epoch =  1 batch =  3
# tensor(9.4509, dtype=torch.float64) tensor(7.9036, dtype=torch.float64) tensor(1.5473, dtype=torch.float64)
# epoch =  1 batch =  4
# tensor(9.4446, dtype=torch.float64) tensor(7.7424, dtype=torch.float64) tensor(1.7022, dtype=torch.float64)
# epoch =  1 batch =  5
# tensor(9.4460, dtype=torch.float64) tensor(7.7125, dtype=torch.float64) tensor(1.7334, dtype=torch.float64)
# epoch =  1 batch =  6
# tensor(9.5058, dtype=torch.float64) tensor(7.8240, dtype=torch.float64) tensor(1.6818, dtype=torch.float64)
# epoch =  1 batch =  7
# tensor(9.5105, dtype=torch.float64) tensor(7.6472, dtype=torch.float64) tensor(1.8633, dtype=torch.float64)
# epoch =  1 batch =  8
# tensor(9.3758, dtype=torch.float64) tensor(7.8718, dtype=torch.float64) tensor(1.5040, dtype=torch.float64)
# epoch =  1 batch =  9
# tensor(9.5901, dtype=torch.float64) tensor(7.8714, dtype=torch.float64) tensor(1.7187, dtype=torch.float64)
# epoch =  1 batch =  10
# tensor(9.5565, dtype=torch.float64) tensor(7.8415, dtype=torch.float64) tensor(1.7150, dtype=torch.float64)
# epoch =  1 batch =  11
# tensor(9.5991, dtype=torch.float64) tensor(7.7919, dtype=torch.float64) tensor(1.8072, dtype=torch.float64)
# epoch =  1 batch =  12
# tensor(9.5965, dtype=torch.float64) tensor(7.7270, dtype=torch.float64) tensor(1.8695, dtype=torch.float64)
# epoch =  1 batch =  13
# tensor(9.6160, dtype=torch.float64) tensor(7.7913, dtype=torch.float64) tensor(1.8248, dtype=torch.float64)
# epoch =  1 batch =  14
# tensor(9.5029, dtype=torch.float64) tensor(7.7436, dtype=torch.float64) tensor(1.7593, dtype=torch.float64)
# epoch =  1 batch =  15
# tensor(9.5225, dtype=torch.float64) tensor(7.7278, dtype=torch.float64) tensor(1.7947, dtype=torch.float64)
# epoch =  1 batch =  16
# tensor(9.5981, dtype=torch.float64) tensor(7.8414, dtype=torch.float64) tensor(1.7567, dtype=torch.float64)
# epoch =  1 batch =  17
# tensor(9.4936, dtype=torch.float64) tensor(7.8245, dtype=torch.float64) tensor(1.6691, dtype=torch.float64)
# epoch =  1 batch =  18
# tensor(9.4781, dtype=torch.float64) tensor(7.8073, dtype=torch.float64) tensor(1.6709, dtype=torch.float64)
# epoch =  1 batch =  19
# tensor(9.6136, dtype=torch.float64) tensor(7.8250, dtype=torch.float64) tensor(1.7886, dtype=torch.float64)
# epoch =  1 batch =  20
# tensor(9.4582, dtype=torch.float64) tensor(7.7283, dtype=torch.float64) tensor(1.7299, dtype=torch.float64)
# epoch =  1 batch =  21
# tensor(9.6828, dtype=torch.float64) tensor(7.8402, dtype=torch.float64) tensor(1.8426, dtype=torch.float64)
# epoch =  1 batch =  22
# tensor(9.3719, dtype=torch.float64) tensor(7.7281, dtype=torch.float64) tensor(1.6438, dtype=torch.float64)
# epoch =  1 batch =  23
# tensor(9.4387, dtype=torch.float64) tensor(7.8398, dtype=torch.float64) tensor(1.5989, dtype=torch.float64)
# epoch =  1 batch =  24
# tensor(9.5038, dtype=torch.float64) tensor(7.7921, dtype=torch.float64) tensor(1.7116, dtype=torch.float64)
# epoch =  1 batch =  25
# tensor(9.5361, dtype=torch.float64) tensor(7.8889, dtype=torch.float64) tensor(1.6472, dtype=torch.float64)
# epoch =  1 batch =  26
# tensor(9.4950, dtype=torch.float64) tensor(7.8259, dtype=torch.float64) tensor(1.6691, dtype=torch.float64)
# epoch =  1 batch =  27
# tensor(9.4215, dtype=torch.float64) tensor(7.7126, dtype=torch.float64) tensor(1.7089, dtype=torch.float64)
# epoch =  1 batch =  28
# tensor(9.5533, dtype=torch.float64) tensor(7.8410, dtype=torch.float64) tensor(1.7124, dtype=torch.float64)
# epoch =  1 batch =  29
# tensor(9.4770, dtype=torch.float64) tensor(7.7935, dtype=torch.float64) tensor(1.6835, dtype=torch.float64)
# epoch =  1 batch =  30
# tensor(9.7026, dtype=torch.float64) tensor(7.7604, dtype=torch.float64) tensor(1.9422, dtype=torch.float64)
# epoch =  1 batch =  31
# tensor(9.4274, dtype=torch.float64) tensor(7.7277, dtype=torch.float64) tensor(1.6997, dtype=torch.float64)
# epoch =  1 batch =  32
# tensor(9.5336, dtype=torch.float64) tensor(7.7443, dtype=torch.float64) tensor(1.7894, dtype=torch.float64)
# epoch =  1 batch =  33
# tensor(9.6308, dtype=torch.float64) tensor(7.8731, dtype=torch.float64) tensor(1.7578, dtype=torch.float64)
# epoch =  1 batch =  34
# tensor(9.4727, dtype=torch.float64) tensor(7.7441, dtype=torch.float64) tensor(1.7286, dtype=torch.float64)
# epoch =  1 batch =  35
# tensor(9.7386, dtype=torch.float64) tensor(7.8892, dtype=torch.float64) tensor(1.8495, dtype=torch.float64)
# epoch =  1 batch =  36
# tensor(9.5964, dtype=torch.float64) tensor(7.8576, dtype=torch.float64) tensor(1.7388, dtype=torch.float64)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-f1de8836a0e6> in <module>()
#      28         total_loss += loss.data
#      29
# ---> 30         loss.backward()
#      31         for A in net.parameters():
#      32             A.data = A.data.sub_(lr*A.grad.data)
#
# C:\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# C:\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
np.savez(save_PATH+save_filename, param_lst = [A.data.numpy() for A in net.parameters()], loss_lst = loss_lst)

# %%
history = Writer()
n = 18846
for A in net.parameters():
    A.requires_grad = False
for i in range(n):
    inputs, label = dataset[i]
    S_lst = net(inputs)
    S = S_lst[-1]
    history.add_tensor('S',S)
    if (i+1)% 100 == 0:
        print('current at batch:', i+1)

# %%
S_lst = history.get('S')
S = torch.cat(S_lst,0)
print(S.shape)

# %%
S_np = S.numpy()
inv_S = np.linalg.pinv(S_np)
Y_sub = Y1[0:n,:]
Y_pred = S_np@(inv_S@Y_sub)
print(np.sum(np.argmax(Y_pred,1) == np.argmax(Y_sub,1))/n)

np.savez(save_PATH + save_filename, 
param_lst = [A.data.numpy() for A in net.parameters()] , loss_lst = loss_lst, S = S_np, pred=Y_pred)
